# %%
import pandas as pd

# %matplotlib inline

# %%
df = pd.read_csv("../Desktop/Argentina Gross Debt to GDP.csv")
df.head() #this will display the first 5 rows
# Out:
#    Year  DebtPercentGDP
# 0  1992         0.25746
# 1  1993         0.27739
# 2  1994         0.29310
# 3  1995         0.31673
# 4  1996         0.33561

# %%
df.dtypes
# Out:
# Year                int64
# DebtPercentGDP    float64
# dtype: object

# %%
df.plot(kind='scatter',x="Year", y="DebtPercentGDP")

# %%
df["Year"]
df["DebtPercentGDP"]
# Out:
# 0     0.25746
# 1     0.27739
# 2     0.29310
# 3     0.31673
# 4     0.33561
# 5     0.32662
# 6     0.35200
# 7     0.40097
# 8     0.42060
# 9     0.49435
# 10    1.52248
# 11    1.28693
# 12    1.17266
# 13    0.79197
# 14    0.69803
# 15    0.60979
# 16    0.52560
# 17    0.53828
# 18    0.42001
# 19    0.37549
# 20    0.38949
# 21    0.41689
# 22    0.43587
# 23    0.55079
# 24    0.53316
# 25    0.52615
# Name: DebtPercentGDP, dtype: float64

# %%
debt = pd.Series(df["DebtPercentGDP"].values, df["Year"].values)
debt.head()
# Out:
# 1992    0.25746
# 1993    0.27739
# 1994    0.29310
# 1995    0.31673
# 1996    0.33561
# dtype: float64

# %%
debt.plot()

# %% [markdown]
# ## skip rows

# %%
la = pd.read_excel("../Desktop/LA_test.xlsx",skiprows=6, header=None)
la.head(20)
# Out:
#            0                           1                        2          3   \
# 0         NaN                         NaN                      NaN        NaN
# 1   Area code                   Area Name                      NaN  1991–1993
# 2         NaN                         NaN                      NaN        NaN
# 3   E12000001                  NORTH EAST                      NaN        NaN
# 4         NaN                                                  NaN        NaN
# 5   E06000047                         NaN        County Durham UA        72.2
# 6   E06000005                         NaN            Darlington UA       72.1
# 7   E06000001                         NaN            Hartlepool UA       71.7
# 8   E06000002                         NaN         Middlesbrough UA       70.8
# 9   E06000057                         NaN       Northumberland UA        73.1
# 10  E06000003                         NaN  Redcar and Cleveland UA       72.4
# ...

# %%
la.to_csv("../Desktop/LA_pandas.csv")
